# %% [markdown]
# ## Import libraries

# %%
# Download the libraries
# !pip install -q transformers sentence-transformers spacy wordcloud

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 923.3 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install -q pinecone-client[grpc]

# %%
# Import the libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import torch

# %% [markdown]
# ## Load Reviews Dataset

# %%
# Load the data
reviews = pd.read_json("/content/new_reviews.json")
reviews.head()
# Out:
#                                              product  \
# 0  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...
# 1  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...
# 2  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...
# 3  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...
# 4  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...
#
#                                               header  \
# 0  my face tone has improved after 3 weeks of usage
# 1                                            Amazing
# 2                                              Good
# 3                 its nice though a little.bit.itchy
# 4                                            awesome
#
#                                               review date_reviewed
# 0  I would recommend this product to anyone that ...    21-07-2024
# 1                               Works as described\n    19-07-2024
# 2                                        Work for me    15-07-2024
# 3                             Increase the quantity     12-07-2024
# 4                   It understands the assignment ☺️    12-07-2024

# %%
# Drop the null values
reviews.dropna(inplace=True)

# %%
# Combine the header and review columns
reviews["full_review"] = reviews["header"] + "." +  reviews["review"]
reviews["full_review"][0] # view the 1st full review
# Out:
# "my face tone has improved after 3 weeks of usage .I would recommend this product to anyone that has an uneven face. The dark shaded areas and dark spots on the face slowly disappear after 3 weeks of usage. You have to be patient for even 4 months to see progress. So it's all about patience"

# %%
# drop the header & reviwe columns
reviews.drop(columns=["header", "review"], inplace=True)

# %%
# Size of the data
print(f"The dataset has {reviews.shape[0]} rows and {reviews.shape[1]} columns")
# Out:
# The dataset has 6009 rows and 3 columns

# %%
# # The time period of the dataset
# print(f"""The dateset covers the period between {reviews["date_reviewed"].min()} & {reviews["date_reviewed"].max()}""")
# Out:
# The dateset covers the period between 2018-01-11 00:00:00 & 2024-12-07 00:00:00

# %% [markdown]
# ## Load Products Dataset

# %%
# Load the products data
products = pd.read_json("/content/new_product.json")
products.head()
# Out:
#                                              product      price  \
# 0  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...  KSh 1,034
# 1  Garnier Skin Active Hydrabomb Pomegranate Tiss...    KSh 365
# 2  Garnier Skin Active Hydrabomb Chamomile Tissue...    KSh 365
# 3  Garnier Micellar Cleansing Water For Sensitive...    KSh 744
# 4       Garnier Mineral Men Invisible Roll-on - 50ml    KSh 350
#
#             store    brand    avg_rating           number_ratings  \
# 0  Official Store  Garnier  4.4 out of 5  (5334 verified ratings)
# 1  Official Store  Garnier  4.6 out of 5  (1546 verified ratings)
# 2  Official Store  Garnier  4.6 out of 5  (1056 verified ratings)
# 3  Official Store  Garnier  4.5 out of 5  (2018 verified ratings)
# 4  Official Store  Garnier  4.5 out of 5    (65 verified ratings)
#
#           number_reviews
# 0  Product Reviews (875)
# 1  Product Reviews (191)
# 2  Product Reviews (137)
# 3  Product Reviews (356)
# 4   Product Reviews (13)

# %%
# Fill the missing values with Official Store

products["store"].fillna("Official Store", inplace=True)

# %%
products.iloc[np.where(products["number_reviews"].isna())]
# Out:
#                                               product    price  \
# 17  Garnier Ultra Doux Black Charcoal & Nigella Se...  KSh 695
# 22   Garnier Ultra Doux Honey Treasures Shampoo 400ml  KSh 795
# 23      Garnier Ultra Doux Olive Mythic Shampoo 400ml  KSh 795
# 24        Garnier Ultra Doux Mythic Olive Conditioner  KSh 695
# 26  Garnier Ultra Doux Almond Milk Hydrating Condi...  KSh 695
# 27  Garnier Ultra Doux Avocado & Shea Butter Nouri...  KSh 695
# 28  Garnier Ultra Doux Avocado Oil & Shea Butter S...  KSh 795
# 33  Garnier Pure Active Cleanser 3IN1  Clay Wash, ...  KSh 720
#
#              store    brand  avg_rating          number_ratings number_reviews
# 17  Official Store  Garnier  0 out of 5  (No ratings available)            NaN
# 22  Official Store  Garnier  0 out of 5  (No ratings available)            NaN
# 23  Official Store  Garnier  0 out of 5  (No ratings available)            NaN
# 24  Official Store  Garnier  0 out of 5  (No ratings available)            NaN
# 26  Official Store  Garnier  0 out of 5  (No ratings available)            NaN
# 27  Official Store  Garnier  0 out of 5  (No ratings available)            NaN
# 28  Official Store  Garnier  0 out of 5  (No ratings available)            NaN
# 33  Official Store  Garnier  0 out of 5  (No ratings available)            NaN

# %%
# Drop the missing values (number_reviews)
products.dropna(inplace=True)

# %%
# Size of data

print(f"The dataset has {products.shape[0]} rows & {products.shape[1]} columns")
# Out:
# The dataset has 46 rows & 7 columns

# %%
# Remove the currency name & commas in the price column

pattern = r'\,+'
products["price"] = products["price"].apply(lambda x: x.split()[1]).apply(lambda x: re.sub(pattern, "", x)).astype("int64")

# %%
# Get the rating No. only

products["avg_rating"] = products["avg_rating"].apply(lambda x: x.split()[0]).astype("float32")

# %%
# Get the value of the number_ratings

pattern = r'\d+' # define the pattern

products["number_ratings"] = products["number_ratings"].apply(lambda x: " ".join(re.findall(pattern, x))).astype("int64")

# %%
# Cover the column to a string & get the value

pattern = r'\d+' # define the pattern

products["number_reviews"] = products["number_reviews"].apply(lambda x: " ".join(re.findall(pattern, x))).astype("int64")

# %%
products.head()
# Out:
#                                              product  price           store  \
# 0  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Official Store
# 1  Garnier Skin Active Hydrabomb Pomegranate Tiss...    365  Official Store
# 2  Garnier Skin Active Hydrabomb Chamomile Tissue...    365  Official Store
# 3  Garnier Micellar Cleansing Water For Sensitive...    744  Official Store
# 4       Garnier Mineral Men Invisible Roll-on - 50ml    350  Official Store
#
#      brand  avg_rating  number_ratings  number_reviews
# 0  Garnier         4.4            5334             875
# 1  Garnier         4.6            1546             191
# 2  Garnier         4.6            1056             137
# 3  Garnier         4.5            2018             356
# 4  Garnier         4.5              65              13

# %%
products.sort_values(by="number_reviews", ascending=False).head(10)
# Out:
#                                               product  price           store  \
# 0   Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Official Store
# 11  Garnier Even & Matte Vitamin  C Booster Serum ...   1050  Official Store
# 39           Garnier Even & Matte Dark Spot Corrector    542  Official Store
# 49      Garnier Even & Matte Vitamin C Cleansing Foam    579  Official Store
# 3   Garnier Micellar Cleansing Water For Sensitive...    744  Official Store
# 43  Garnier Anti-Blemish Charcoal Serum With AHA+B...   1570  Official Store
# 10  Garnier Even & Matte Vitamin C Protection Crea...    910  Official Store
# 5   Garnier Skin Active Pure Charcoal Black Tissue...    298  Official Store
# 38    Garnier Even & Matte Oily Skin Face Moisturizer    709  Official Store
# 51  Garnier Even & Matte Vitamin  C Micellar Clean...    403  Official Store
#
#       brand  avg_rating  number_ratings  number_reviews
# 0   Garnier         4.4            5334             875
# 11  Garnier         4.3            4553             760
# 39  Garnier         4.0            2997             583
# 49  Garnier         4.4            2435             430
# 3   Garnier         4.5            2018             356
# 43  Garnier         4.2            2203             308
# 10  Garnier         4.2            1701             267
# 5   Garnier         4.4            1954             264
# 38  Garnier         4.0            1191             249
# 51  Garnier         4.4            1238             240

# %% [markdown]
# ## Merge Reviews & Dataset

# %%
df = pd.merge(products, reviews, on="product", how="inner")
df.shape[0]
# Out:
# 6116

# %%
# df.to_csv("garnier.csv")

# %%
df["product"].nunique()
# Out:
# 45

# %%
df.head()
# Out:
#                                              product  price           store  \
# 0  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Official Store
# 1  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Official Store
# 2  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Official Store
# 3  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Official Store
# 4  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Official Store
#
#      brand  avg_rating  number_ratings  number_reviews date_reviewed  \
# 0  Garnier         4.4            5334             875    21-07-2024
# 1  Garnier         4.4            5334             875    19-07-2024
# 2  Garnier         4.4            5334             875    15-07-2024
# 3  Garnier         4.4            5334             875    12-07-2024
# 4  Garnier         4.4            5334             875    12-07-2024
#
#                                          full_review
# 0  my face tone has improved after 3 weeks of usa...
# 1                       Amazing.Works as described\n
# 2                                  Good .Work for me
# 3  its nice though a little.bit.itchy.Increase th...
# 4           awesome.It understands the assignment ☺️

# %%
# More Feature engineering

df.drop(columns=["store", "number_reviews", "number_ratings"], inplace=True) # drop named columns

df.rename({"avg_rating": "average_rating", "date_reviewed": "date", "full_review": "review"}, inplace=True, axis=1) # rename the highlighted columns

df.head()
# Out:
#                                              product  price    brand  \
# 0  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Garnier
# 1  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Garnier
# 2  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Garnier
# 3  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Garnier
# 4  Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Garnier
#
#    average_rating        date  \
# 0             4.4  21-07-2024
# 1             4.4  19-07-2024
# 2             4.4  15-07-2024
# 3             4.4  12-07-2024
# 4             4.4  12-07-2024
#
#                                               review
# 0  my face tone has improved after 3 weeks of usa...
# 1                       Amazing.Works as described\n
# 2                                  Good .Work for me
# 3  its nice though a little.bit.itchy.Increase th...
# 4           awesome.It understands the assignment ☺️

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6116 entries, 0 to 6115
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product         6116 non-null   object
#  1   price           6116 non-null   int64
#  2   brand           6116 non-null   object
#  3   average_rating  6116 non-null   float32
#  4   date            6116 non-null   object
#  5   review          6116 non-null   object
# dtypes: float32(1), int64(1), object(4)
# memory usage: 262.9+ KB

# %%
# Determine the device

device = torch.cuda.current_device() if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %% [markdown]
# ## Sentiment Analysis

# %%
# Hugging Face
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

model_id = "cardiffnlp/twitter-roberta-base-sentiment-latest"

# Load the model from hugging face
model = AutoModelForSequenceClassification.from_pretrained(
    model_id,
    num_labels=3
)

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Load the model & tokenizer into the pipeline
nlp = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device,
    top_k = 1
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
# Confirm effectiveness of the model

test_review = df["review"].iloc[:5].to_list()
test_review
# Out:
# ["my face tone has improved after 3 weeks of usage .I would recommend this product to anyone that has an uneven face. The dark shaded areas and dark spots on the face slowly disappear after 3 weeks of usage. You have to be patient for even 4 months to see progress. So it's all about patience",
#  'Amazing.Works as described\n',
#  'Good .Work for me',
#  'its nice though a little.bit.itchy.Increase the quantity ',
#  'awesome.It understands the assignment ☺️']

# %%
nlp(test_review)
# Out:
# [[{'label': 'positive', 'score': 0.9084731936454773}],
#  [{'label': 'positive', 'score': 0.967121422290802}],
#  [{'label': 'positive', 'score': 0.930743932723999}],
#  [{'label': 'positive', 'score': 0.7437677383422852}],
#  [{'label': 'positive', 'score': 0.9810640811920166}]]

# %% [markdown]
# ## Embedding

# %%
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer

# Determine the model
model = "sentence-transformers/all-MiniLM-L6-v2"

# Initialize the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model, do_lower_case=True)

# Determine the embedding Model
retriever = SentenceTransformer(model, tokenizer, device=device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
retriever
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
# test
emb = retriever.encode(df["review"][:3])
emb
# Out:
# array([[ 0.00652468, -0.05481092,  0.0777772 , ..., -0.09992243,
#         -0.05175291,  0.01842107],
#        [-0.11751407,  0.04538532, -0.0490553 , ...,  0.04613779,
#         -0.07503618,  0.09133487],
#        [-0.08677332, -0.00530554, -0.02227135, ..., -0.09145427,
#         -0.08304647,  0.05306825]], dtype=float32)

# %% [markdown]
# ## Vector Database

# %%
# Import PineCone Vectordb library
from pinecone.grpc import PineconeGRPC as Pinecone
from pinecone import ServerlessSpec

# Load the api-key
pc = Pinecone(api_key="2588c502-bac6-4f85-b582-3079cf1e28c9")

# %%
retriever.get_sentence_embedding_dimension()
# Out:
# 384

# %%
# Define the Index name

index_name = "garnier-sentiments-kenya"

# Check if index exists
if index_name not in pc.list_indexes().names():
  # Create index if it does not exist
  pc.create_index(
      index_name,
      dimension=retriever.get_sentence_embedding_dimension(),
      metric="cosine",
      spec=ServerlessSpec(
          cloud="aws",
          region="us-east-1")
      )

# connect to the index created
index = pc.Index(index_name)

# %%
def get_sentiment(reviews):

  labels = []

  scores = []

  for review in reviews:

    sentiment = nlp(review)[0][0]

    labels.append(sentiment["label"])

    scores.append(sentiment["score"])

  return labels, scores

# %%
# Create timestamps
from dateutil.parser import parse

def get_timestamp(dates):

  timestamps = [parse(d).timestamp() for d in dates]

  return timestamps

# %%
from tqdm.auto import tqdm


# determine the batch size
batch_size = 128

# Create the for loop
for i in tqdm(range(0, len(df), batch_size)):

  #find end of batch
  i_end = min(i+batch_size, len(df))

  # extract batch
  batch = df.iloc[i:i_end].copy()

  #generate embeddings for search
  emb = retriever.encode(batch["review"].to_list())

  # convert reviewed data to timesatamps to enable filtering
  timestamp = get_timestamp(batch["date"].to_list())
  batch["timestamp"] = timestamp

  # get sentiment lable & score for each batch
  label, score = get_sentiment(batch["review"])
  batch["sentiment_label"] = label
  batch["sentiment_score"] = score

  # Additional details like price in metadata
  meta = batch.to_dict(orient="records")

  # Create unique ids
  ids = [f"{idx}" for idx in range(i, i_end)]

  # add all to upsert list
  to_upsert = list(zip(ids, emb, meta))

  # insert the records to pinecone
  _ = index.upsert(vectors=to_upsert)
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]

# %%
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 6116}},
#  'total_vector_count': 6116}

# %%
query = "What's the overall sentiments of all our products"

# Create Dense embedding on the query
xq = retriever.encode(query)

# Query the database
results = index.query(xq, include_metadata=True, top_k=6116)

# %%
results["matches"]
# Out:
# [{'id': '1952',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '22-12-2023',
#                'price': 2167.0,
#                'product': 'Garnier AHA+BHA Charcoal Serum + Pure Active 3-in-1 '
#                           'Charcoal Mask (Anti Acne Skin Care Kit)',
#                'review': 'quality.Product as expected ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.508845329284668,
#                'timestamp': 1703203200.0},
#   'score': 0.5080197,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1953',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '22-12-2023',
#                'price': 2167.0,
#                'product': 'Garnier AHA+BHA Charcoal Serum + Pure Active 3-in-1 '
#                           'Charcoal Mask (Anti Acne Skin Care Kit)',
#                'review': 'quality.Product as expected ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.508845329284668,
#                'timestamp': 1703203200.0},
#   'score': 0.5080197,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4222',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '24-06-2022',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'good product.Increase the quantity of the products',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8472294807434082,
#                'timestamp': 1656028800.0},
#   'score': 0.4948662,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3823',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '22-06-2022',
#                'price': 709.0,
#                'product': 'Garnier Even & Matte Oily Skin Face Moisturizer',
#                'review': 'product is good.Quantity is less',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.5481253266334534,
#                'timestamp': 1655856000.0},
#   'score': 0.47078726,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1684',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '14-12-2021',
#                'price': 298.0,
#                'product': 'Garnier Skin Active Pure Charcoal Black Tissue Face '
#                           'Mask',
#                'review': 'branded product.Quantity',
#                'sentiment_label': 'neutral',
#                'sentiment_score': 0.8363181352615356,
#                'timestamp': 1639440000.0},
#   'score': 0.46129605,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1227',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '12-06-2023',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'I like it.Product is as expected',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9283561706542969,
#                'timestamp': 1701820800.0},
#   'score': 0.45367128,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1106',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '18-02-2022',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Chamomile Tissue Face '
#                           'Mask',
#                'review': 'products.I really  love it',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.979098916053772,
#                'timestamp': 1645142400.0},
#   'score': 0.44567364,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2351',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '25-09-2023',
#                'price': 910.0,
#                'product': 'Garnier Even & Matte Vitamin C Protection Cream '
#                           'SPF30 50ml',
#                'review': 'Good product.So far so good ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9781813025474548,
#                'timestamp': 1695600000.0},
#   'score': 0.4444954,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3774',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '01-02-2024',
#                'price': 709.0,
#                'product': 'Garnier Even & Matte Oily Skin Face Moisturizer',
#                'review': 'Everything .Good product\n',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9062007665634155,
#                'timestamp': 1704153600.0},
#   'score': 0.4412585,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1159',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '17-12-2020',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Chamomile Tissue Face '
#                           'Mask',
#                'review': "Great product. I'm happy..As expected",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9885744452476501,
#                'timestamp': 1608163200.0},
#   'score': 0.43946227,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1771',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '17-12-2020',
#                'price': 298.0,
#                'product': 'Garnier Skin Active Pure Charcoal Black Tissue Face '
#                           'Mask',
#                'review': "Great product. I'm happy..As expected",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9885744452476501,
#                'timestamp': 1608163200.0},
#   'score': 0.43946227,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3726',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '17-12-2020',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Green Tea Tissue Face '
#                           'Mask',
#                'review': "Great product. I'm happy..As expected",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9885744452476501,
#                'timestamp': 1608163200.0},
#   'score': 0.43946227,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3619',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '17-12-2020',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Green Tea Tissue Face '
#                           'Mask',
#                'review': "Great product. I'm happy..As expected",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9885744452476501,
#                'timestamp': 1608163200.0},
#   'score': 0.43946227,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3531',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '24-05-2019',
#                'price': 1295.0,
#                'product': 'Garnier Pure Active 3 In 1 Wash',
#                'review': 'Great product.So far so good...',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9863699674606323,
#                'timestamp': 1558656000.0},
#   'score': 0.4369627,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5862',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '01-09-2022',
#                'price': 403.0,
#                'product': 'Garnier Even & Matte Vitamin  C Micellar Cleansing '
#                           'Water - 400ml',
#                'review': 'good product.good ????????',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.6383108496665955,
#                'timestamp': 1641686400.0},
#   'score': 0.43366775,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2216',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '29-09-2020',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Cotton Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'Ok. Product.The scent is just ok. Nothing fancy about '
#                          'it',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.7646607756614685,
#                'timestamp': 1601337600.0},
#   'score': 0.43261594,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4007',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '26-11-2018',
#                'price': 709.0,
#                'product': 'Garnier Even & Matte Oily Skin Face Moisturizer',
#                'review': 'new product.It is good so far.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9812561869621277,
#                'timestamp': 1543190400.0},
#   'score': 0.42701903,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1907',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '28-06-2024',
#                'price': 2167.0,
#                'product': 'Garnier AHA+BHA Charcoal Serum + Pure Active 3-in-1 '
#                           'Charcoal Mask (Anti Acne Skin Care Kit)',
#                'review': 'good product.Just as I expected ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9714168310165405,
#                'timestamp': 1719532800.0},
#   'score': 0.42412952,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5554',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '17-06-2021',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'Genuine product.As expected',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.6447746157646179,
#                'timestamp': 1623888000.0},
#   'score': 0.42048615,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2058',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '14-08-2023',
#                'price': 2960.0,
#                'product': 'Garnier Charcoal Serum With AHA+BHA 30ml Twin Pack',
#                'review': 'Excellent product.So far in love with the product. '
#                          'Great and fresh scent too????????.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9879591464996338,
#                'timestamp': 1691971200.0},
#   'score': 0.42017347,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4432',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '07-12-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'great.The product is very very good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9836785197257996,
#                'timestamp': 1626048000.0},
#   'score': 0.4146435,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '355',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '17-10-2022',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'the product is magic on my face ..The quality and '
#                          'quantity',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9465639591217041,
#                'timestamp': 1665964800.0},
#   'score': 0.4125617,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2849',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '06-12-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'Affordable.Affordable price and quality product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.7845519185066223,
#                'timestamp': 1654992000.0},
#   'score': 0.41200647,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5715',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '11-09-2023',
#                'price': 2215.0,
#                'product': 'Garnier Vitamin C Booster Serum 30ml Twin Pack',
#                'review': 'I love it.So far so good. The product is good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9886882901191711,
#                'timestamp': 1699488000.0},
#   'score': 0.4113535,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3332',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '22-11-2023',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Floral Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'mixed feelings.am not so sure to feel about this '
#                          "product because i don't like its scent",
#                'sentiment_label': 'negative',
#                'sentiment_score': 0.8810103535652161,
#                'timestamp': 1700611200.0},
#   'score': 0.41123354,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5448',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '31-12-2021',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'products.Works perfectly',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9198178052902222,
#                'timestamp': 1640908800.0},
#   'score': 0.40869063,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2535',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '06-05-2024',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'Okay product.Okay product',
#                'sentiment_label': 'neutral',
#                'sentiment_score': 0.6779439449310303,
#                'timestamp': 1717545600.0},
#   'score': 0.40375277,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4678',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '12-11-2018',
#                'price': 545.0,
#                'product': 'Garnier Micellar Oil-Infused Cleansing Water (Oil In '
#                           'Water) - 100ml',
#                'review': 'Awesome feel.Amazing product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9814079403877258,
#                'timestamp': 1544486400.0},
#   'score': 0.40368313,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5220',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '06-05-2024',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'Okay product.Okay product',
#                'sentiment_label': 'neutral',
#                'sentiment_score': 0.6779439449310303,
#                'timestamp': 1717545600.0},
#   'score': 0.40346915,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1410',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '04-03-2021',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': "I just love the product.I'm yet to get to a point "
#                          'where I can tell more about the product. Maybe after '
#                          'I use it for not less than 2 weeks. So far so good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9757586717605591,
#                'timestamp': 1617408000.0},
#   'score': 0.40215603,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '417',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '03-06-2022',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'Quality.Good discount. The product works perfectly.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9682199358940125,
#                'timestamp': 1646524800.0},
#   'score': 0.4020761,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4200',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '22-08-2022',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'your products are used.My product is half empty total '
#                          'rip off',
#                'sentiment_label': 'negative',
#                'sentiment_score': 0.9167316555976868,
#                'timestamp': 1661126400.0},
#   'score': 0.40084508,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2792',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '13-02-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': "Does best.It's a amazing product ????????????",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9735822677612305,
#                'timestamp': 1676246400.0},
#   'score': 0.39900386,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1546',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '20-12-2018',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'good product.Good Product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9449912309646606,
#                'timestamp': 1545264000.0},
#   'score': 0.39879248,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1702',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '30-11-2021',
#                'price': 298.0,
#                'product': 'Garnier Skin Active Pure Charcoal Black Tissue Face '
#                           'Mask',
#                'review': 'Good Product.Good product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9451083540916443,
#                'timestamp': 1638230400.0},
#   'score': 0.39879248,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4687',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '07-09-2023',
#                'price': 395.0,
#                'product': 'Garnier Ampoule Tissue Face Mask - Watermelon And 1% '
#                           'Hyaluronic Acid 15g',
#                'review': 'good product.Good product ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9342893958091736,
#                'timestamp': 1688860800.0},
#   'score': 0.39879248,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4466',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '26-11-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'Good product.Good product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9460539221763611,
#                'timestamp': 1637884800.0},
#   'score': 0.39879248,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4535',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '21-09-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'Quantity.Improve the quantity of the product...it '
#                          'very little',
#                'sentiment_label': 'neutral',
#                'sentiment_score': 0.590495228767395,
#                'timestamp': 1632182400.0},
#   'score': 0.398569,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '356',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '10-10-2022',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': "it's really good.This product is surprisingly good.. "
#                          "Doesn't react to sensitive skin.. Felt Smooth and is "
#                          'definitely a good purchase',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9794331789016724,
#                'timestamp': 1665360000.0},
#   'score': 0.39810276,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1652',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '21-03-2022',
#                'price': 298.0,
#                'product': 'Garnier Skin Active Pure Charcoal Black Tissue Face '
#                           'Mask',
#                'review': 'Great.Lovely product.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9813740849494934,
#                'timestamp': 1647820800.0},
#   'score': 0.39764187,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4541',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '15-09-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'great product good price.good product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9641638398170471,
#                'timestamp': 1631664000.0},
#   'score': 0.39707822,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5070',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '14-11-2023',
#                'price': 350.0,
#                'product': 'Garnier Mineral Women Even Extra Roll-on - 50ml',
#                'review': 'quality product .Good ???? ',
#                'sentiment_label': 'neutral',
#                'sentiment_score': 0.5719187259674072,
#                'timestamp': 1699920000.0},
#   'score': 0.39577675,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3545',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '29-05-2024',
#                'price': 2185.0,
#                'product': 'Garnier Boost It Up Bundle',
#                'review': 'Product review .The products really worked ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.970945417881012,
#                'timestamp': 1716940800.0},
#   'score': 0.39264616,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '270',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '28-12-2022',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'Amazing.My all time favorite product.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9857289791107178,
#                'timestamp': 1672185600.0},
#   'score': 0.39226222,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5461',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '10-12-2021',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'Good rating.Great product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9622185826301575,
#                'timestamp': 1633996800.0},
#   'score': 0.39184275,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '449',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '28-03-2022',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'good product.Effective product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9140867590904236,
#                'timestamp': 1648425600.0},
#   'score': 0.39163095,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4112',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '29-06-2023',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': '????????.The product is perfect',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9653552770614624,
#                'timestamp': 1687996800.0},
#   'score': 0.39135602,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1908',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '24-06-2024',
#                'price': 2167.0,
#                'product': 'Garnier AHA+BHA Charcoal Serum + Pure Active 3-in-1 '
#                           'Charcoal Mask (Anti Acne Skin Care Kit)',
#                'review': 'amazing.the product is amazing',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9844602942466736,
#                'timestamp': 1719187200.0},
#   'score': 0.39095968,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3406',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '13-03-2022',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Floral Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'Great product.The smell',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.973448634147644,
#                'timestamp': 1647129600.0},
#   'score': 0.39022988,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1890',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '03-07-2023',
#                'price': 1822.0,
#                'product': 'Garnier Charcoal Serum + Even & Matte UV Protection '
#                           'SPF 30 (Skin Care Kit)',
#                'review': 'I like the product.Delivery took a while but product '
#                          'is working miracles',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9696886539459229,
#                'timestamp': 1678147200.0},
#   'score': 0.3884972,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4666',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '28-05-2020',
#                'price': 545.0,
#                'product': 'Garnier Micellar Oil-Infused Cleansing Water (Oil In '
#                           'Water) - 100ml',
#                'review': 'very good.The quality of product and the packaging',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.976698100566864,
#                'timestamp': 1590624000.0},
#   'score': 0.38831264,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1855',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '05-01-2024',
#                'price': 1822.0,
#                'product': 'Garnier Charcoal Serum + Even & Matte UV Protection '
#                           'SPF 30 (Skin Care Kit)',
#                'review': 'Good products.The packaging was aight and the '
#                          'products work well',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9696314930915833,
#                'timestamp': 1714521600.0},
#   'score': 0.38817653,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5639',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '24-06-2024',
#                'price': 2215.0,
#                'product': 'Garnier Vitamin C Booster Serum 30ml Twin Pack',
#                'review': 'Good.Product was good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9432954788208008,
#                'timestamp': 1719187200.0},
#   'score': 0.38781902,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3277',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '10-11-2023',
#                'price': 350.0,
#                'product': 'Garnier Protection 5 Mens Roll-on - 50ml',
#                'review': "I don't like.Product wasn't delivered",
#                'sentiment_label': 'negative',
#                'sentiment_score': 0.8913689255714417,
#                'timestamp': 1696982400.0},
#   'score': 0.38780808,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2678',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '24-07-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'A favorite.Only good things to say about this '
#                          'product, it has become a staple',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9788758754730225,
#                'timestamp': 1690156800.0},
#   'score': 0.38747108,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4720',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '26-06-2024',
#                'price': 1570.0,
#                'product': 'Garnier Anti-Blemish Charcoal Serum With AHA+BHA & '
#                           'Niacinamide For Acne Prone Skin',
#                'review': 'Good product.Fair price ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.93707674741745,
#                'timestamp': 1719360000.0},
#   'score': 0.38672665,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2209',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '02-02-2021',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Cotton Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'good product.The smell',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9369778633117676,
#                'timestamp': 1612224000.0},
#   'score': 0.38604683,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '465',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '10-03-2022',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'Great Product.Value for Money!',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9796439409255981,
#                'timestamp': 1664755200.0},
#   'score': 0.38566783,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '464',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '10-03-2022',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'Great Product.Value for Money!',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9796439409255981,
#                'timestamp': 1664755200.0},
#   'score': 0.38566783,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3731',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '30-11-2020',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Green Tea Tissue Face '
#                           'Mask',
#                'review': 'Like.It is a good product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9193592667579651,
#                'timestamp': 1606694400.0},
#   'score': 0.38520858,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3624',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '30-11-2020',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Green Tea Tissue Face '
#                           'Mask',
#                'review': 'Like.It is a good product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9193592667579651,
#                'timestamp': 1606694400.0},
#   'score': 0.38520852,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1500',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '15-04-2020',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': "I love it.The product came in god's condition",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.988088071346283,
#                'timestamp': 1586908800.0},
#   'score': 0.3845894,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '146',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '14-08-2023',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'good.Quality product ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9052010178565979,
#                'timestamp': 1691971200.0},
#   'score': 0.38390374,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1863',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '24-11-2023',
#                'price': 1822.0,
#                'product': 'Garnier Charcoal Serum + Even & Matte UV Protection '
#                           'SPF 30 (Skin Care Kit)',
#                'review': 'nice packaging.Started using the products today '
#                          'hoping for the best outcome.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9710507392883301,
#                'timestamp': 1700784000.0},
#   'score': 0.3838275,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5815',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '06-01-2023',
#                'price': 403.0,
#                'product': 'Garnier Even & Matte Vitamin  C Micellar Cleansing '
#                           'Water - 400ml',
#                'review': 'I love it..Love the product. Already feeling good '
#                          'about it.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9892005920410156,
#                'timestamp': 1685577600.0},
#   'score': 0.38381872,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2630',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '29-08-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': "its good.It's a good product so far",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.975426435470581,
#                'timestamp': 1693267200.0},
#   'score': 0.38268533,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4583',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '25-02-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'Mixed feelings.Not so sure about it. Plus the product '
#                          'is too little.',
#                'sentiment_label': 'negative',
#                'sentiment_score': 0.8889977931976318,
#                'timestamp': 1614211200.0},
#   'score': 0.38139468,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5058',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '22-05-2024',
#                'price': 350.0,
#                'product': 'Garnier Mineral Women Even Extra Roll-on - 50ml',
#                'review': 'good product.The authenticity ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9238070845603943,
#                'timestamp': 1716336000.0},
#   'score': 0.381088,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3187',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '07-12-2021',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': "An excellentproduct.I've used the product. So far so "
#                          'good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9865619540214539,
#                'timestamp': 1626048000.0},
#   'score': 0.38099074,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4465',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '26-11-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'increase product quantity.Still using the product so '
#                          'far so good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9373959302902222,
#                'timestamp': 1637884800.0},
#   'score': 0.38041484,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3329',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '28-11-2023',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Floral Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'Good product.Smells so nice ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9830161929130554,
#                'timestamp': 1701129600.0},
#   'score': 0.38038003,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2851',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '06-12-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'the product is the as expected.Delivery was as '
#                          'expected',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.5545187592506409,
#                'timestamp': 1654992000.0},
#   'score': 0.38010126,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3326',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '08-12-2023',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Floral Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'great. Product is great but they take ages to deliver '
#                          'products, a total turn off',
#                'sentiment_label': 'negative',
#                'sentiment_score': 0.9160085916519165,
#                'timestamp': 1691798400.0},
#   'score': 0.37979382,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '644',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '18-11-2021',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'I love it.Best products',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9845788478851318,
#                'timestamp': 1637193600.0},
#   'score': 0.3792176,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5347',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '09-12-2022',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'Product.Makes the skin even',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.7255757451057434,
#                'timestamp': 1662940800.0},
#   'score': 0.3791887,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '200',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '26-06-2023',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': "Great product.Few weeks in, I'm happy",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9880311489105225,
#                'timestamp': 1687737600.0},
#   'score': 0.37918082,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5829',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '16-11-2022',
#                'price': 403.0,
#                'product': 'Garnier Even & Matte Vitamin  C Micellar Cleansing '
#                           'Water - 400ml',
#                'review': 'Never disappoint.Awesome product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9739713668823242,
#                'timestamp': 1668556800.0},
#   'score': 0.37909475,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '918',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '04-04-2022',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Pomegranate Tissue '
#                           'Face Mask',
#                'review': 'Product and service.Product is effective and service '
#                          'was good and prompt',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9409427642822266,
#                'timestamp': 1649030400.0},
#   'score': 0.37865293,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3234',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '18-11-2021',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'great.Such a good product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9798563718795776,
#                'timestamp': 1637193600.0},
#   'score': 0.37795234,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1452',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '03-10-2020',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'Holy Grail.This, great product ????',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8601090312004089,
#                'timestamp': 1583798400.0},
#   'score': 0.37755737,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5075',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '11-08-2023',
#                'price': 350.0,
#                'product': 'Garnier Mineral Women Even Extra Roll-on - 50ml',
#                'review': 'Lovely .Great product ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9796782732009888,
#                'timestamp': 1699401600.0},
#   'score': 0.3767262,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2920',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '10-10-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'GOOD PACKAGING JUST AS ADVERTISED..So far so good.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9851385951042175,
#                'timestamp': 1665360000.0},
#   'score': 0.37648347,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5869',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '19-07-2022',
#                'price': 403.0,
#                'product': 'Garnier Even & Matte Vitamin  C Micellar Cleansing '
# ...
#                'sentiment_score': 0.9836164712905884,
#                'timestamp': 1699315200.0},
#   'score': 0.26175186,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2120',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '07-07-2023',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Cotton Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'I like it Smells good.Smells good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9678801894187927,
#                'timestamp': 1688688000.0},
#   'score': 0.26172447,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '703',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '06-09-2021',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'i love it.i love the smell and it leaves my face so '
#                          'smooth.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.979953408241272,
#                'timestamp': 1623196800.0},
#   'score': 0.26154277,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4540',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '17-09-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'quality.Delivery on time',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8265873193740845,
#                'timestamp': 1631836800.0},
#   'score': 0.26153696,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3397',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '23-05-2022',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Floral Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'I love love it.It smells amazing',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9857861995697021,
#                'timestamp': 1653264000.0},
#   'score': 0.26145574,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2775',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '17-03-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'The item is good.But it was half full when it '
#                          'came.Its good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9435623288154602,
#                'timestamp': 1679011200.0},
#   'score': 0.26142368,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1519',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '26-11-2019',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'Love it.Awesome product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9811295866966248,
#                'timestamp': 1574726400.0},
#   'score': 0.26127797,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1979',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '19-10-2023',
#                'price': 2167.0,
#                'product': 'Garnier AHA+BHA Charcoal Serum + Pure Active 3-in-1 '
#                           'Charcoal Mask (Anti Acne Skin Care Kit)',
#                'review': 'best.What i expected am super happy',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9860668778419495,
#                'timestamp': 1697673600.0},
#   'score': 0.2612018,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2580',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '07-01-2024',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'I love it.The best Vitamin C serum out there.....100% '
#                          'legit. \r\n'
#                          'Highly recommend',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9840519428253174,
#                'timestamp': 1719792000.0},
#   'score': 0.26118052,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '6034',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '28-08-2021',
#                'price': 949.0,
#                'product': 'Garnier Micellar Oil-Infused Cleansing Water (Oil In '
#                           'Water) - 400ml',
#                'review': 'I love it..Quality product, good price, worth the '
#                          'wait.\r\n'
#                          'Please inform us to collect the product using sms or '
#                          'a call too.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9692810773849487,
#                'timestamp': 1630108800.0},
#   'score': 0.26116344,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2013',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '24-05-2023',
#                'price': 2167.0,
#                'product': 'Garnier AHA+BHA Charcoal Serum + Pure Active 3-in-1 '
#                           'Charcoal Mask (Anti Acne Skin Care Kit)',
#                'review': 'I love it.Great product for the skin',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9865784049034119,
#                'timestamp': 1684886400.0},
#   'score': 0.26111096,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1127',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '17-09-2021',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Chamomile Tissue Face '
#                           'Mask',
#                'review': 'Awesome.Always a reliable product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9741335511207581,
#                'timestamp': 1631836800.0},
#   'score': 0.26100263,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1838',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '15-07-2024',
#                'price': 1822.0,
#                'product': 'Garnier Charcoal Serum + Even & Matte UV Protection '
#                           'SPF 30 (Skin Care Kit)',
#                'review': 'ORIGINAL PRODUCT.The products came as advertised, my '
#                          'wife loves them, she says they are garnier original '
#                          'products.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9626935124397278,
#                'timestamp': 1721001600.0},
#   'score': 0.26099885,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1375',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '31-08-2021',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'Garnier fan.Great product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9549459218978882,
#                'timestamp': 1630368000.0},
#   'score': 0.26098013,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2172',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '30-03-2022',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Cotton Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'Nice.It smells soo good.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.979840874671936,
#                'timestamp': 1648598400.0},
#   'score': 0.26094332,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3109',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '02-02-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'Its okay.So far so good, waiting to see results',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9496970772743225,
#                'timestamp': 1643760000.0},
#   'score': 0.26084995,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2991',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '27-05-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'Imitation product.The product I received is different '
#                          'from what Garnier is marketing. Package was really '
#                          'wanting, had been tampered with. The delivery agent '
#                          'insisted it was caused by mishandling but on opening '
#                          'I realized the product was different.',
#                'sentiment_label': 'negative',
#                'sentiment_score': 0.837834358215332,
#                'timestamp': 1653609600.0},
#   'score': 0.26076713,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3400',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '04-04-2022',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Floral Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'roll.on.Fragrance is sweet smelling',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8512259721755981,
#                'timestamp': 1649030400.0},
#   'score': 0.26071212,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4652',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '02-09-2021',
#                'price': 545.0,
#                'product': 'Garnier Micellar Oil-Infused Cleansing Water (Oil In '
#                           'Water) - 100ml',
#                'review': 'Amazing.Awesome! Miscellar products do not '
#                          'dissapoint. It cleanses my skin well leaving it with '
#                          'a moisturized feeling',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.981280505657196,
#                'timestamp': 1612828800.0},
#   'score': 0.26069525,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3954',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '05-10-2020',
#                'price': 709.0,
#                'product': 'Garnier Even & Matte Oily Skin Face Moisturizer',
#                'review': "I like it.Been using it for a while it's a nice "
#                          'product just dont use alot to avoid the whitish '
#                          'residue apart from that love it, delivery was fast',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9469390511512756,
#                'timestamp': 1589068800.0},
#   'score': 0.26068285,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1044',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '12-03-2020',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Pomegranate Tissue '
#                           'Face Mask',
#                'review': 'awesome.loved the product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9813810586929321,
#                'timestamp': 1606953600.0},
#   'score': 0.2606054,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3489',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '19-10-2021',
#                'price': 1295.0,
#                'product': 'Garnier Pure Active 3 In 1 Wash',
#                'review': 'i like it.Just as advertised',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9179330468177795,
#                'timestamp': 1634601600.0},
#   'score': 0.26049957,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '12-07-2024',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'its nice though a little.bit.itchy.Increase the '
#                          'quantity ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.7437677383422852,
#                'timestamp': 1733529600.0},
#   'score': 0.26047686,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2142',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '23-12-2022',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Cotton Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'sweet scent.Love it',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9672237634658813,
#                'timestamp': 1671753600.0},
#   'score': 0.26046243,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3853',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '02-02-2022',
#                'price': 709.0,
#                'product': 'Garnier Even & Matte Oily Skin Face Moisturizer',
#                'review': 'Scammed.The product was delivered but it was less '
#                          'than half full more watery substance and some very '
#                          'small cream after I really squeezed from the bottle. '
#                          'Someone interfered with the real product. So '
#                          'dissapointing.',
#                'sentiment_label': 'negative',
#                'sentiment_score': 0.9278720021247864,
#                'timestamp': 1643760000.0},
#   'score': 0.26040047,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4489',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '18-11-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': "I like it.So far so good.. It doesn't leave your face "
#                          'oily which I like.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.941378653049469,
#                'timestamp': 1637193600.0},
#   'score': 0.26036066,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  ...]

# %%
def count_sentiment(result):

  sentiments = {
      "negative": 0,
      "neutral": 0,
      "positive": 0
  }

  # Iterate through the search results
  for r in results["matches"]:
    #extract sentiment label and it's count
    sentiments[r["metadata"]["sentiment_label"]] += 1

  return sentiments

# %%
sentiment = count_sentiment(results)
sentiment
# Out:
# {'negative': 664, 'neutral': 459, 'positive': 4993}

# %%
# Plot the sentiment on the price
import seaborn as sns

# Set the color pallete
sns.set_palette("muted")
sns.despine()
plt.figure(figsize=(7, 8))

# Create the barplot
ax  = sns.barplot(x=list(sentiment.keys()), y=list(sentiment.values()))

# Add titles
ax.set_title('Overall sentiments by Number of Reviews')
ax.set_xlabel('Sentiment')
ax.set_ylabel('Number of reviews')

# Define grid
ax.yaxis.grid(True, linestyle='--', alpha=0.7)

# Add labels
for p in ax.patches:
    ax.annotate(format(p.get_height().astype(int)),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')

plt.rc('font', size=14)  # controls default text sizes
plt.rc('axes', titlesize=15)  # fontsize of the axes title
plt.rc('axes', labelsize=15)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=12)  # fontsize of the tick labels
plt.rc('ytick', labelsize=12)  # fontsize of the tick labels


plt.show();

# %%
products.sort_values(by="number_ratings", ascending=False).head()
# Out:
#                                               product  price           store  \
# 0   Garnier Pure Active 3 In1 Charcoal  Anti  Blac...   1034  Official Store
# 11  Garnier Even & Matte Vitamin  C Booster Serum ...   1050  Official Store
# 39           Garnier Even & Matte Dark Spot Corrector    542  Official Store
# 49      Garnier Even & Matte Vitamin C Cleansing Foam    579  Official Store
# 43  Garnier Anti-Blemish Charcoal Serum With AHA+B...   1570  Official Store
#
#       brand  avg_rating  number_ratings  number_reviews
# 0   Garnier         4.4            5334             875
# 11  Garnier         4.3            4553             760
# 39  Garnier         4.0            2997             583
# 49  Garnier         4.4            2435             430
# 43  Garnier         4.2            2203             308

# %%
products["product"].iloc[11]
# Out:
# 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.'

# %%
query = "what are the best features"

# Create Dense embedding on the query
xq = retriever.encode(query)

# Query the database
results = index.query(xq, include_metadata=True, top_k=1000, filter={"$or": [{"sentiment_label": {"$eq": "positive"}}, {"sentiment_score": {"$gte": 0.80}}]})

# %%
results["matches"]
# Out:
# [{'id': '4454',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '02-12-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': '????????????????.Best product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9298836588859558,
#                'timestamp': 1613088000.0},
#   'score': 0.44475332,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '487',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '17-02-2022',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'THE BEST.????????????????????????',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9214547276496887,
#                'timestamp': 1645056000.0},
#   'score': 0.37969312,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '862',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '22-06-2019',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'Multi purpose.It&#039;s been a week now not much '
#                          'change but I like that it&#039;s versatile',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8719165325164795,
#                'timestamp': 1561161600.0},
#   'score': 0.3757949,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4026',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '05-04-2024',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'best product.It good quality \n',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9170443415641785,
#                'timestamp': 1714780800.0},
#   'score': 0.3753977,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4292',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '18-03-2022',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'the best.Quick transformation',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9512124061584473,
#                'timestamp': 1647561600.0},
#   'score': 0.37516397,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2873',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '22-11-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'love it.Simply the best????',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9846087098121643,
#                'timestamp': 1669075200.0},
#   'score': 0.3745111,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2703',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '11-07-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'Beauty.Quality is super b .',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9482067823410034,
#                'timestamp': 1699315200.0},
#   'score': 0.37309557,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4450',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '02-12-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'Performance.It good n helps fo remove deep spots',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8875762224197388,
#                'timestamp': 1613088000.0},
#   'score': 0.36878538,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2849',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '06-12-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'Affordable.Affordable price and quality product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.7845519185066223,
#                'timestamp': 1654992000.0},
#   'score': 0.3598692,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2678',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '24-07-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'A favorite.Only good things to say about this '
#                          'product, it has become a staple',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9788758754730225,
#                'timestamp': 1690156800.0},
#   'score': 0.3594766,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '918',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '04-04-2022',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Pomegranate Tissue '
#                           'Face Mask',
#                'review': 'Product and service.Product is effective and service '
#                          'was good and prompt',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9409427642822266,
#                'timestamp': 1649030400.0},
#   'score': 0.35932615,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2881',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '16-11-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'amazing.Fast And reliable',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9690945148468018,
#                'timestamp': 1668556800.0},
#   'score': 0.35129282,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2440',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '03-01-2023',
#                'price': 910.0,
#                'product': 'Garnier Even & Matte Vitamin C Protection Cream '
#                           'SPF30 50ml',
#                'review': 'the best qiality.Works so perfect and so natural',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.967975378036499,
#                'timestamp': 1677628800.0},
#   'score': 0.35089782,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4834',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '24-11-2023',
#                'price': 1570.0,
#                'product': 'Garnier Anti-Blemish Charcoal Serum With AHA+BHA & '
#                           'Niacinamide For Acne Prone Skin',
#                'review': 'Affordability.Great on skin',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.898048460483551,
#                'timestamp': 1700784000.0},
#   'score': 0.3463356,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1748',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '14-07-2021',
#                'price': 298.0,
#                'product': 'Garnier Skin Active Pure Charcoal Black Tissue Face '
#                           'Mask',
#                'review': 'cosmetic.Very good result',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9678342938423157,
#                'timestamp': 1626220800.0},
#   'score': 0.34501275,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2604',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '23-10-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'i like it.Reliable services',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9500585794448853,
#                'timestamp': 1698019200.0},
#   'score': 0.3437738,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3546',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '08-12-2023',
#                'price': 2185.0,
#                'product': 'Garnier Boost It Up Bundle',
#                'review': 'Boost it up bundle..Great products,false advertising. '
#                          'You get two sheet masks not three as product images.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8725020289421082,
#                'timestamp': 1691798400.0},
#   'score': 0.3431336,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4964',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '04-08-2023',
#                'price': 1570.0,
#                'product': 'Garnier Anti-Blemish Charcoal Serum With AHA+BHA & '
#                           'Niacinamide For Acne Prone Skin',
#                'review': 'texture.Feels soft on skin and really works on the '
#                          'blemishes.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.813701868057251,
#                'timestamp': 1680912000.0},
#   'score': 0.33812913,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2605',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '18-10-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'Great.Best thing to ever purchase ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9833230376243591,
#                'timestamp': 1697587200.0},
#   'score': 0.33725095,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1415',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '06-02-2021',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': "the best.It's clear everything",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9700498580932617,
#                'timestamp': 1622592000.0},
#   'score': 0.3369279,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5495',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '04-11-2021',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'best one can afford.Works well on face and sport '
#                          'remover',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8684661388397217,
#                'timestamp': 1618099200.0},
#   'score': 0.33637527,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1376',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '30-08-2021',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'Best.Best product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9629268050193787,
#                'timestamp': 1630281600.0},
#   'score': 0.33633506,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4969',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '31-07-2023',
#                'price': 1570.0,
#                'product': 'Garnier Anti-Blemish Charcoal Serum With AHA+BHA & '
#                           'Niacinamide For Acne Prone Skin',
#                'review': 'Fast delivery and reliability.Yet to use it. ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.5256423950195312,
#                'timestamp': 1690761600.0},
#   'score': 0.33631992,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '964',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '03-11-2021',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Pomegranate Tissue '
#                           'Face Mask',
#                'review': 'Face mask.Good services',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8568958640098572,
#                'timestamp': 1615420800.0},
#   'score': 0.3352879,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2792',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '13-02-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': "Does best.It's a amazing product ????????????",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9735822677612305,
#                'timestamp': 1676246400.0},
#   'score': 0.33404115,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5144',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '11-06-2020',
#                'price': 439.0,
#                'product': 'Garnier Micellar Water Sensitive Skin - 100ml',
#                'review': 'great.Easy to use',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9663487672805786,
#                'timestamp': 1604620800.0},
#   'score': 0.333428,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3685',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '18-02-2022',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Green Tea Tissue Face '
#                           'Mask',
#                'review': 'face mask.The best I have ever bought',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9767159819602966,
#                'timestamp': 1645142400.0},
#   'score': 0.33251348,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3578',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '18-02-2022',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Green Tea Tissue Face '
#                           'Mask',
#                'review': 'face mask.The best I have ever bought',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9767159819602966,
#                'timestamp': 1645142400.0},
#   'score': 0.33251348,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3138',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '21-01-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'I like.Timely delivery and good customer service',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.958405077457428,
#                'timestamp': 1642723200.0},
#   'score': 0.33138356,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4560',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '16-08-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'I like.Have just started using it I will give back '
#                          'more details after use.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9375777840614319,
#                'timestamp': 1629072000.0},
#   'score': 0.33078167,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '156',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '09-08-2023',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'face mask.Skin friendly,delivers results 100%',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8655713200569153,
#                'timestamp': 1694131200.0},
#   'score': 0.32714644,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '554',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '12-12-2021',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'quality.its very effective',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9560035467147827,
#                'timestamp': 1639267200.0},
#   'score': 0.3269513,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5752',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '10-06-2024',
#                'price': 403.0,
#                'product': 'Garnier Even & Matte Vitamin  C Micellar Cleansing '
#                           'Water - 400ml',
#                'review': 'the best.Removes it all',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9449768662452698,
#                'timestamp': 1728172800.0},
#   'score': 0.32607198,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4407',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '15-12-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'the texture.It works perfectly',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9235033988952637,
#                'timestamp': 1639526400.0},
#   'score': 0.3231199,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4408',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '15-12-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'the texture.It works perfectly',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9235033988952637,
#                'timestamp': 1639526400.0},
#   'score': 0.3231199,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4409',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '15-12-2021',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'the texture.It works perfectly',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9235033988952637,
#                'timestamp': 1639526400.0},
#   'score': 0.3231199,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '669',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '15-10-2021',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': "the best.It's the best product that I have ever "
#                          'seen...it work well',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9878473281860352,
#                'timestamp': 1634256000.0},
#   'score': 0.32232067,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5248',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '07-12-2023',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'The best.I highly recommend it',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9813491702079773,
#                'timestamp': 1689120000.0},
#   'score': 0.321458,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5277',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '29-08-2023',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'I like it.Easy to use',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9509298801422119,
#                'timestamp': 1693267200.0},
#   'score': 0.32035372,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1106',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '18-02-2022',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Chamomile Tissue Face '
#                           'Mask',
#                'review': 'products.I really  love it',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.979098916053772,
#                'timestamp': 1645142400.0},
#   'score': 0.31894094,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2285',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '22-03-2024',
#                'price': 910.0,
#                'product': 'Garnier Even & Matte Vitamin C Protection Cream '
#                           'SPF30 50ml',
#                'review': 'amazing.a very good sucscreen.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.977586030960083,
#                'timestamp': 1711065600.0},
#   'score': 0.31821206,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2015',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '17-05-2023',
#                'price': 2167.0,
#                'product': 'Garnier AHA+BHA Charcoal Serum + Pure Active 3-in-1 '
#                           'Charcoal Mask (Anti Acne Skin Care Kit)',
#                'review': 'it is the best.The delivery guy Claudio Kimani is '
#                          'very friendly and the products are superb',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9834255576133728,
#                'timestamp': 1684281600.0},
#   'score': 0.31819183,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4203',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '18-08-2022',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'performance.Very effective',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9349009394645691,
#                'timestamp': 1660780800.0},
#   'score': 0.31756032,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2612',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '25-09-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'The best.The best product I have used',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9836026430130005,
#                'timestamp': 1695600000.0},
#   'score': 0.31568384,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5603',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '23-11-2020',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'I love it.Gives the best services',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9834885001182556,
#                'timestamp': 1606089600.0},
#   'score': 0.31487828,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2926',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '05-10-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'the best.My face looks so nice',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9858360290527344,
#                'timestamp': 1652140800.0},
#   'score': 0.31137592,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '563',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '07-12-2021',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'Awesomeness.Make it available countrywide',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9734945893287659,
#                'timestamp': 1626048000.0},
#   'score': 0.311196,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4783',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '11-03-2024',
#                'price': 1570.0,
#                'product': 'Garnier Anti-Blemish Charcoal Serum With AHA+BHA & '
#                           'Niacinamide For Acne Prone Skin',
#                'review': 'the best so far.It is the best... doing what is '
#                          'supposed to do',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9823792576789856,
#                'timestamp': 1730592000.0},
#   'score': 0.31083202,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '97',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '06-11-2023',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'I love it.Easy to use, ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9863763451576233,
#                'timestamp': 1686441600.0},
#   'score': 0.30925804,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5303',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '11-07-2023',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'its the best.The quality',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9748486876487732,
#                'timestamp': 1699315200.0},
#   'score': 0.30645385,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1165',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '10-11-2020',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Chamomile Tissue Face '
#                           'Mask',
#                'review': 'Face Mask.I am pleased with the product.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9710472226142883,
#                'timestamp': 1602374400.0},
#   'score': 0.30499125,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1205',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '28-06-2024',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'micellar water, bluetooth earphones.Everything was '
#                          'great',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9614672064781189,
#                'timestamp': 1719532800.0},
#   'score': 0.30401218,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '99',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '31-10-2023',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'i like it.Am yet to see changes...but i have only '
#                          'used it once..',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.7616705298423767,
#                'timestamp': 1698710400.0},
#   'score': 0.30374667,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4727',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '17-06-2024',
#                'price': 1570.0,
#                'product': 'Garnier Anti-Blemish Charcoal Serum With AHA+BHA & '
#                           'Niacinamide For Acne Prone Skin',
#                'review': 'Glow.Really work on my face well and the glow ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8246318697929382,
#                'timestamp': 1718582400.0},
#   'score': 0.30304417,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '565',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '07-12-2021',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'Awesome product.Very efficient and purposeful',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9810991883277893,
#                'timestamp': 1626048000.0},
#   'score': 0.3024947,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3041',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '18-03-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'best.Even skin',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8398003578186035,
#                'timestamp': 1647561600.0},
#   'score': 0.30248028,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '110',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '20-09-2023',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'i love it affordable also.Perfecto',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9790522456169128,
#                'timestamp': 1695168000.0},
#   'score': 0.3015397,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3471',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '03-05-2024',
#                'price': 600.0,
#                'product': 'Garnier Even & Matte Cleansing Foam 100ml',
#                'review': 'I LOVE IOT.I LOVE THE EFFECIENCY',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9810872673988342,
#                'timestamp': 1709596800.0},
#   'score': 0.30071196,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '374',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '06-09-2022',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': "It works.I'm a first-time user and I love it so far",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9855247139930725,
#                'timestamp': 1654732800.0},
#   'score': 0.29879355,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4378',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '14-01-2022',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'dark spot corrector.I like',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.5713958144187927,
#                'timestamp': 1642118400.0},
#   'score': 0.29873526,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '686',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '26-09-2021',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'The best!.Keeps face very soft and acne free!',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9765952825546265,
#                'timestamp': 1632614400.0},
#   'score': 0.298637,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2082',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '08-04-2024',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Cotton Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'smells nice.Smells so good \n',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9653717875480652,
#                'timestamp': 1722729600.0},
#   'score': 0.2982802,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3464',
#   'metadata': {'average_rating': 3.200000047683716,
#                'brand': 'Garnier',
#                'date': '01-07-2020',
#                'price': 650.0,
#                'product': 'Garnier Color Naturals Fr/gb/ar 4',
#                'review': "performance.Make a product that does what it's "
#                          'supposed to do. Zero colour, changes hair texture. '
#                          'Total disappointment',
#                'sentiment_label': 'negative',
#                'sentiment_score': 0.8504142761230469,
#                'timestamp': 1578355200.0},
#   'score': 0.29737893,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3064',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '28-02-2022',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'Best product there ever will be.Perfect as it is. '
#                          'Flawless face',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9820559620857239,
#                'timestamp': 1646006400.0},
#   'score': 0.2972431,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3219',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '23-11-2021',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'vitaminc booster.Skin smooth, though waiting to see '
#                          'if my spots will disappear, but so far soo good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9188960194587708,
#                'timestamp': 1637625600.0},
#   'score': 0.29717588,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3220',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '23-11-2021',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'vitaminc booster.Skin smooth, though waiting to see '
#                          'if my spots will disappear, but so far soo good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9188960194587708,
#                'timestamp': 1637625600.0},
#   'score': 0.29717588,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2416',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '08-05-2023',
#                'price': 910.0,
#                'product': 'Garnier Even & Matte Vitamin C Protection Cream '
#                           'SPF30 50ml',
#                'review': 'good as always!.My favourite  ???? sunscreen and '
#                          'moisturiser thanks ????',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9878467917442322,
#                'timestamp': 1691193600.0},
#   'score': 0.29710773,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5100',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '16-03-2022',
#                'price': 439.0,
#                'product': 'Garnier Micellar Water Sensitive Skin - 100ml',
#                'review': 'love it.Affordable and nice',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9773922562599182,
#                'timestamp': 1647388800.0},
#   'score': 0.29690343,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2110',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '19-09-2023',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Cotton Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': "The best.The best,doesn't have alcohol ",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9468219876289368,
#                'timestamp': 1695081600.0},
#   'score': 0.2959959,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1418',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '10-01-2021',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'Like it.Best product',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9632383584976196,
#                'timestamp': 1633046400.0},
#   'score': 0.2958883,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '440',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '06-04-2022',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'the best.I would advise everyone to buy it ,I myself '
#                          'was impressed',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9847191572189331,
#                'timestamp': 1654300800.0},
#   'score': 0.29523,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4925',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '22-08-2023',
#                'price': 1570.0,
#                'product': 'Garnier Anti-Blemish Charcoal Serum With AHA+BHA & '
#                           'Niacinamide For Acne Prone Skin',
#                'review': 'Best product.Have a glowing skin\n\n',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.963409960269928,
#                'timestamp': 1692662400.0},
#   'score': 0.2950398,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5862',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '01-09-2022',
#                'price': 403.0,
#                'product': 'Garnier Even & Matte Vitamin  C Micellar Cleansing '
#                           'Water - 400ml',
#                'review': 'good product.good ????????',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.6383108496665955,
#                'timestamp': 1641686400.0},
#   'score': 0.29331696,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4699',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '08-02-2022',
#                'price': 395.0,
#                'product': 'Garnier Ampoule Tissue Face Mask - Watermelon And 1% '
#                           'Hyaluronic Acid 15g',
#                'review': 'Face mask.Smelt nice, good pacakaging, plenty of '
#                          'serum but It was abit too sticky for my liking.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.6177389025688171,
#                'timestamp': 1659398400.0},
#   'score': 0.2918188,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '6064',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '27-09-2020',
#                'price': 949.0,
#                'product': 'Garnier Micellar Oil-Infused Cleansing Water (Oil In '
#                           'Water) - 400ml',
#                'review': "Best.It's simply the best",
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9706864356994629,
#                'timestamp': 1601164800.0},
#   'score': 0.2901998,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '166',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '24-07-2023',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'best.The best purchase ever',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.983349084854126,
#                'timestamp': 1690156800.0},
#   'score': 0.28967196,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '51',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '05-03-2024',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': '????????????????.Great ????I love it',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9803573489189148,
#                'timestamp': 1714694400.0},
#   'score': 0.28937194,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3724',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '04-02-2021',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Green Tea Tissue Face '
#                           'Mask',
#                'review': '??????.Just what I have been looking for.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.812111496925354,
#                'timestamp': 1617321600.0},
#   'score': 0.28922024,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3617',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '04-02-2021',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Green Tea Tissue Face '
#                           'Mask',
#                'review': '??????.Just what I have been looking for.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.812111496925354,
#                'timestamp': 1617321600.0},
#   'score': 0.28922024,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1869',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '23-10-2023',
#                'price': 1822.0,
#                'product': 'Garnier Charcoal Serum + Even & Matte UV Protection '
#                           'SPF 30 (Skin Care Kit)',
#                'review': 'fast delivery.Best combo ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9754791855812073,
#                'timestamp': 1698019200.0},
#   'score': 0.28853425,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3508',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '25-10-2019',
#                'price': 1295.0,
#                'product': 'Garnier Pure Active 3 In 1 Wash',
#                'review': 'Love it.The quality is top notch',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9825078845024109,
#                'timestamp': 1571961600.0},
#   'score': 0.28731734,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5448',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '31-12-2021',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'products.Works perfectly',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9198178052902222,
#                'timestamp': 1640908800.0},
#   'score': 0.28714678,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3716',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '26-05-2021',
# ...
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'perfect.Quality',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9296653270721436,
#                'timestamp': 1643068800.0},
#   'score': 0.18662979,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4356',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '25-01-2022',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'perfect.Quality',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9296653270721436,
#                'timestamp': 1643068800.0},
#   'score': 0.18662979,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3517',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '17-07-2019',
#                'price': 1295.0,
#                'product': 'Garnier Pure Active 3 In 1 Wash',
#                'review': 'love it.cleanses the skin perfectly',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9764190316200256,
#                'timestamp': 1563321600.0},
#   'score': 0.1865676,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '6062',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '14-10-2020',
#                'price': 949.0,
#                'product': 'Garnier Micellar Oil-Infused Cleansing Water (Oil In '
#                           'Water) - 400ml',
#                'review': 'I love it!.I have oily acne prone skin but this works '
#                          'great on my skin! and it smells great too!',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9794368147850037,
#                'timestamp': 1602633600.0},
#   'score': 0.18636136,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2806',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '05-01-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': "it's great.Have ised it for quite a long time and "
#                          'will continue using it. It corrected all my dark '
#                          'sports. \n'
#                          "It's highly sun sensitive which is not good, even "
#                          "with a sunscreen, I'd advice that you don't use it if "
#                          'you are having much exposure to the sun',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9167528748512268,
#                'timestamp': 1682899200.0},
#   'score': 0.1863508,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '143',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '17-08-2023',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'I like it..Has a great smell and leaves skin very '
#                          'soft',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9774709939956665,
#                'timestamp': 1692230400.0},
#   'score': 0.18634541,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4867',
#   'metadata': {'average_rating': 4.199999809265137,
#                'brand': 'Garnier',
#                'date': '02-10-2023',
#                'price': 1570.0,
#                'product': 'Garnier Anti-Blemish Charcoal Serum With AHA+BHA & '
#                           'Niacinamide For Acne Prone Skin',
#                'review': 'I like it.Legit for the purpose',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.913680374622345,
#                'timestamp': 1675987200.0},
#   'score': 0.18626957,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5765',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '28-02-2024',
#                'price': 403.0,
#                'product': 'Garnier Even & Matte Vitamin  C Micellar Cleansing '
#                           'Water - 400ml',
#                'review': 'I LOVE IT.REAL DEAL FOR MY MONEY',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9818914532661438,
#                'timestamp': 1709078400.0},
#   'score': 0.18626025,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4068',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '14-08-2023',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'darkspot.It works my dark spots cleared ',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.6668393611907959,
#                'timestamp': 1691971200.0},
#   'score': 0.18625823,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '6',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '09-07-2024',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'garnier.Delivered fast n works well for me \n',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8849549293518066,
#                'timestamp': 1725667200.0},
#   'score': 0.18621987,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1865',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '17-11-2023',
#                'price': 1822.0,
#                'product': 'Garnier Charcoal Serum + Even & Matte UV Protection '
#                           'SPF 30 (Skin Care Kit)',
#                'review': 'I like it.The best product ever my face is smooth n '
#                          'glowing',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9854345321655273,
#                'timestamp': 1700179200.0},
#   'score': 0.18620259,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '916',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '14-04-2022',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Pomegranate Tissue '
#                           'Face Mask',
#                'review': 'face mask review.the best garnier face mask period. '
#                          'so relaxing, so soothing and leaves skin feeling so '
#                          'plump.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9796484112739563,
#                'timestamp': 1649894400.0},
#   'score': 0.18618464,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2646',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '18-08-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'i love it.it works on my skin so perfectly.  its been '
#                          'almost two weeks and my skin looks so good.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9860638380050659,
#                'timestamp': 1692316800.0},
#   'score': 0.18609563,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1343',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '03-11-2021',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'Amazing.????????????????No words',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9391813278198242,
#                'timestamp': 1615420800.0},
#   'score': 0.18604787,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '3331',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '22-11-2023',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Floral Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'Scent .Smells so niiice!!!',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9586888551712036,
#                'timestamp': 1700611200.0},
#   'score': 0.18599863,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1257',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '04-07-2022',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'I like it.Removes make up well',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9396963119506836,
#                'timestamp': 1649289600.0},
#   'score': 0.18585205,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '5329',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '17-03-2023',
#                'price': 579.0,
#                'product': 'Garnier Even & Matte Vitamin C Cleansing Foam',
#                'review': 'I love it.The results can be seen from the very first '
#                          'day of use, I love it',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9865476489067078,
#                'timestamp': 1679011200.0},
#   'score': 0.18584843,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2667',
#   'metadata': {'average_rating': 4.300000190734863,
#                'brand': 'Garnier',
#                'date': '26-07-2023',
#                'price': 1050.0,
#                'product': 'Garnier Even & Matte Vitamin  C Booster Serum 30ml.',
#                'review': 'review.Its working magic on my face. This is the '
#                          'second week of use and my skin tone is  more even and '
#                          'the glow. I love it.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9800574779510498,
#                'timestamp': 1690329600.0},
#   'score': 0.18584181,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2178',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '10-03-2022',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Cotton Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'cheap.Very good',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9480577111244202,
#                'timestamp': 1664755200.0},
#   'score': 0.18545517,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1538',
#   'metadata': {'average_rating': 4.5,
#                'brand': 'Garnier',
#                'date': '04-06-2019',
#                'price': 744.0,
#                'product': 'Garnier Micellar Cleansing Water For Sensitive Skin '
#                           '- 400ml',
#                'review': 'Great product .a very good makeup remover and '
#                          'cleanser. I love it',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9854583740234375,
#                'timestamp': 1554508800.0},
#   'score': 0.18540184,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1096',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '27-06-2022',
#                'price': 365.0,
#                'product': 'Garnier Skin Active Hydrabomb Chamomile Tissue Face '
#                           'Mask',
#                'review': 'I love it.Leaves skin feeling soft and clear.',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9770318865776062,
#                'timestamp': 1656288000.0},
#   'score': 0.18537112,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '1587',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '07-09-2023',
#                'price': 298.0,
#                'product': 'Garnier Skin Active Pure Charcoal Black Tissue Face '
#                           'Mask',
#                'review': 'fast delivery.Fast',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8748295307159424,
#                'timestamp': 1688860800.0},
#   'score': 0.18536828,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4693',
#   'metadata': {'average_rating': 4.599999904632568,
#                'brand': 'Garnier',
#                'date': '28-10-2022',
#                'price': 395.0,
#                'product': 'Garnier Ampoule Tissue Face Mask - Watermelon And 1% '
#                           'Hyaluronic Acid 15g',
#                'review': 'Superb.The mask really does give an instant glow to '
#                          'the skin , also the smell is amazing',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9813389778137207,
#                'timestamp': 1666915200.0},
#   'score': 0.18527597,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '49',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '07-03-2024',
#                'price': 1034.0,
#                'product': 'Garnier Pure Active 3 In1 Charcoal  Anti  Blackhead '
#                           'Mask Wash Scrub -150ml',
#                'review': 'Great.No more breakouts and really cleanses',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.8685243725776672,
#                'timestamp': 1719964800.0},
#   'score': 0.18518789,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '2194',
#   'metadata': {'average_rating': 4.400000095367432,
#                'brand': 'Garnier',
#                'date': '19-10-2021',
#                'price': 348.0,
#                'product': 'Garnier Protection 6 In 1 Cotton Fresh Womens '
#                           'Roll-on - 50ml',
#                'review': 'smelling good.Nice smell',
#                'sentiment_label': 'positive',
#                'sentiment_score': 0.9573777318000793,
#                'timestamp': 1634601600.0},
#   'score': 0.18514553,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []},
#  {'id': '4152',
#   'metadata': {'average_rating': 4.0,
#                'brand': 'Garnier',
#                'date': '29-11-2022',
#                'price': 542.0,
#                'product': 'Garnier Even & Matte Dark Spot Corrector',
#                'review': 'Garnier.Reacted on my face big time and got me the '
#                          'grandest skin break out had to discontinue after 2 '
#                          'months of consistent usage.\n'
#                          'Always felt a burning sensation upon application.',
#                'sentiment_label': 'negative',
#                'sentiment_score': 0.9125431776046753,
#                'timestamp': 1669680000.0},
#   'score': 0.18496893,
#   'sparse_values': {'indices': [], 'values': []},
#   'values': []}]

# %%
# results["matches"][0]["metadata"]["review"]

# Define the function to get the positive reviews
def get_positive_reviews(result):

  reviews = []

  for r in result["matches"]:

    reviews.append(r["metadata"]["review"])

  return " ".join(reviews)

# %%
# Call the function to get the reviews
positive_reviews = get_positive_reviews(results).lower()

import spacy

nlp = spacy.load("en_core_web_lg")

positive_texts = [token.lemma_ for token in nlp(positive_reviews) if token not in token.is_stop and token not in token.is_punct]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ee079841ddc1> in <cell line: 2>()
#       1 # Call the function to get the reviews
# ----> 2 positive_reviews = get_positive_reviews(results).lower()
#       3
#       4 import spacy
#       5
#
# NameError: name 'get_positive_reviews' is not defined

# %%
positive_texts
# Out:
# ['.best',
#  'product',
#  'good',
#  'multi',
#  'purpose.it&#039;',
#  'week',
#  'change',
#  'like',
#  'it&#039;',
#  'versatile',
#  'good',
#  'product.it',
#  'good',
#  'quality',
#  '\n ',
#  'best.quick',
#  'transformation',
#  'love',
#  'it.simply',
#  'good',
#  'beauty.quality',
#  'super',
#  'b',
#  'performance.it',
#  'good',
#  'n',
#  'help',
#  'fo',
#  'remove',
#  'deep',
#  'spot',
#  'affordable.affordable',
#  'price',
#  'quality',
#  'product',
#  'favorite.only',
#  'good',
#  'thing',
#  'product',
#  'staple',
#  'product',
#  'service.product',
#  'effective',
#  'service',
#  'good',
#  'prompt',
#  'amazing.fast',
#  'reliable',
#  'good',
#  'qiality.work',
#  'perfect',
#  'natural',
#  'affordability.great',
#  'skin',
#  'cosmetic.very',
#  'good',
#  'result',
#  'like',
#  'it.reliable',
#  'service',
#  'boost',
#  'bundle',
#  'great',
#  'product',
#  'false',
#  'advertising',
#  'sheet',
#  'mask',
#  'product',
#  'image',
#  'texture.feel',
#  'soft',
#  'skin',
#  'work',
#  'blemish',
#  'great.b',
#  'thing',
#  'purchase',
#  ' ',
#  'best.it',
#  'clear',
#  'good',
#  'afford.work',
#  'face',
#  'sport',
#  'remover',
#  'best.b',
#  'product',
#  'fast',
#  'delivery',
#  'reliability.yet',
#  'use',
#  ' ',
#  'face',
#  'mask.good',
#  'service',
#  'best.it',
#  'amazing',
#  'product',
#  'great.easy',
#  'use',
#  'face',
#  'mask.the',
#  'good',
#  'buy',
#  'face',
#  'mask.the',
#  'good',
#  'buy',
#  'like.timely',
#  'delivery',
#  'good',
#  'customer',
#  'service',
#  'like.have',
#  'start',
#  'detail',
#  'use',
#  'face',
#  'mask.skin',
#  'friendly',
#  'deliver',
#  'result',
#  '100',
#  'quality.its',
#  'effective',
#  'best.remove',
#  'texture.it',
#  'work',
#  'perfectly',
#  'texture.it',
#  'work',
#  'perfectly',
#  'texture.it',
#  'work',
#  'perfectly',
#  'best.it',
#  'good',
#  'product',
#  'see',
#  'work',
#  'best.i',
#  'highly',
#  'recommend',
#  'like',
#  'it.easy',
#  'use',
#  'products.i',
#  ' ',
#  'love',
#  'amazing.a',
#  'good',
#  'sucscreen',
#  'best.the',
#  'delivery',
#  'guy',
#  'claudio',
#  'kimani',
#  'friendly',
#  'product',
#  'superb',
#  'performance.very',
#  'effective',
#  'best.the',
#  'good',
#  'product',
#  'love',
#  'it.give',
#  'good',
#  'service',
#  'best.my',
#  'face',
#  'look',
#  'nice',
#  'awesomeness.make',
#  'available',
#  'countrywide',
#  'good',
#  'far.it',
#  'good',
#  'suppose',
#  'love',
#  'it.easy',
#  'use',
#  ' ',
#  'best.the',
#  'quality',
#  'face',
#  'mask.i',
#  'pleased',
#  'product',
#  'micellar',
#  'water',
#  'bluetooth',
#  'earphones.everythe',
#  'great',
#  'like',
#  'it.am',
#  'change',
#  'glow.really',
#  'work',
#  'face',
#  'glow',
#  ' ',
#  'awesome',
#  'product.very',
#  'efficient',
#  'purposeful',
#  'best.even',
#  'skin',
#  'love',
#  'affordable',
#  'also.perfecto',
#  'love',
#  'iot.i',
#  'love',
#  'effeciency',
#  "works.i'm",
#  'time',
#  'user',
#  'love',
#  'far',
#  'dark',
#  'spot',
#  'corrector.i',
#  'like',
#  'best!.keeps',
#  'face',
#  'soft',
#  'acne',
#  'free',
#  'smell',
#  'nice.smell',
#  'good',
#  '\n ',
#  'performance.make',
#  'product',
#  'suppose',
#  'zero',
#  'colour',
#  'change',
#  'hair',
#  'texture',
#  'total',
#  'disappointment',
#  'good',
#  'product',
#  'be.perfect',
#  'flawless',
#  'face',
#  'vitaminc',
#  'booster.skin',
#  'smooth',
#  'wait',
#  'spot',
#  'disappear',
#  'far',
#  'soo',
#  'good',
#  'vitaminc',
#  'booster.skin',
#  'smooth',
#  'wait',
#  'spot',
#  'disappear',
#  'far',
#  'soo',
#  'good',
#  'good',
#  'always!.my',
#  'favourite',
#  ' ',
#  'sunscreen',
#  'moisturiser',
#  'thank',
#  'love',
#  'it.affordable',
#  'nice',
#  'best.the',
#  'good',
#  "doesn't",
#  'alcohol',
#  ' ',
#  'like',
#  'it.b',
#  'product',
#  'best.i',
#  'advise',
#  'buy',
#  'impress',
#  'well',
#  'product.have',
#  'glow',
#  'skin',
#  '\n\n ',
#  'good',
#  'product.good',
#  'face',
#  'mask.smelt',
#  'nice',
#  'good',
#  'pacakaging',
#  'plenty',
#  'serum',
#  'abit',
#  'sticky',
#  'liking',
#  'best.it',
#  'simply',
#  'good',
#  'best.the',
#  'good',
#  'purchase',
#  '.great',
#  'love',
#  '.just',
#  'look',
#  '.just',
#  'look',
#  'fast',
#  'delivery.b',
#  'combo',
#  ' ',
#  'love',
#  'it.the',
#  'quality',
#  'notch',
#  'products.work',
#  'perfectly',
#  'facial.the',
#  'delivery',
#  'prompt',
#  'product',
#  'great',
#  'skin',
#  'facial.the',
#  'delivery',
#  'prompt',
#  'product',
#  'great',
#  'skin',
#  'dark',
#  'spot',
#  'corrector.good',
#  'tiny',
#  'love',
#  'it.it',
#  'work',
#  'change',
#  'face',
#  'best.no',
#  'scent',
#  'texture.excellent',
#  'garnier.its',
#  'easy',
#  'transparent',
#  'quality.met',
#  'expectation',
#  'love',
#  'it.quality',
#  'product',
#  '\n',
#  'good',
#  'far',
#  'beat',
#  'buy.b',
#  'product',
#  'quality.light',
#  'skin',
#  'quality.light',
#  'skin',
#  'overrate',
#  'expensive',
#  'nothing.it',
#  'simply',
#  'overrated',
#  'make',
#  'face',
#  'extra',
#  'shiny',
#  'oily',
#  'dark',
#  'spot',
#  'daily',
#  'month',
#  'vitamin',
#  'c',
#  'booster.so',
#  'far',
#  'good',
#  'experience',
#  'magic',
#  'honestly',
#  'boost',
#  'confidence',
#  'high',
#  'feel',
#  'beautiful',
#  'well',
#  'like',
#  'progress',
#  'smell.it',
#  'good',
#  ' ',
#  'oduor',
#  'corrector.so',
#  'far',
#  'good',
#  'good',
#  'buy',
#  'good',
#  'product',
#  'face.just',
#  'good',
#  'quality.good',
#  'worth',
#  'price',
#  'love',
#  'it.like',
#  'need',
#  'wash',
#  'application',
#  'value',
#  'money.work',
#  'good.b',
#  'product',
#  'good',
#  'ever.financially',
#  'favorable',
#  'u',
#  'vitamin',
#  'c',
#  'sun',
#  'screen',
#  'quality.and',
#  'time.the',
#  'quality',
#  'great',
#  'work',
#  'deliver',
#  'time',
#  'subsequent',
#  'purchase',
#  'quality.and',
#  'time.the',
#  'quality',
#  'great',
#  'work',
#  'deliver',
#  'time',
#  'subsequent',
#  'purchase',
#  'perfect.what',
#  'ask',
#  'work',
#  'perfectly',
#  'quality.good',
#  'mennd',
#  'woman',
#  'work',
#  'wonder',
#  'skin',
#  'love',
#  'it.its',
#  'quality',
#  'like',
#  'it.the',
#  'product',
#  'work',
#  'wonder',
#  '3',
#  'day',
#  'spot',
#  'change',
#  'best.eagerly',
#  'wait',
#  'result',
#  'new',
#  'start',
#  'notice',
#  'change',
#  'bravoo',
#  'great',
#  'skin',
#  'care',
#  'routines.easy',
#  'use',
#  'usage',
#  'results.clarity',
#  'skin',
#  'work',
#  'performance.work',
#  'describe',
#  'love',
#  'it.i',
#  'improvement',
#  'help',
#  'productreview.work',
#  'skin',
#  'recommend',
#  'skin.it',
#  'give',
#  'face',
#  'smooth',
#  'look',
#  'best.b',
#  'product',
#  'buy',
#  'match',
#  'description.highly',
#  'recommend',
#  'instant',
#  'result',
#  '.good',
#  'result',
#  ' ',
#  'love',
#  'it.saw',
#  'change',
#  'week',
#  'consistent',
#  'application',
#  'face',
#  'mask.instant',
#  'glow',
#  'nice',
#  'good.it',
#  'easy',
#  'use',
#  'favourite.favourite',
#  'great',
#  'result',
#  'favourite.favourite',
#  'great',
#  'result',
#  'like',
#  'it.just',
#  'need',
#  'good',
#  'product',
#  'like',
#  'it.just',
#  'need',
#  'good',
#  'product',
#  'cleansing',
#  'foam.so',
#  'far',
#  'good',
#  'leave',
#  'skin',
#  'soft',
#  'start',
#  'see',
#  'change',
#  'far',
#  '2',
#  'week',
#  'nice',
#  'product.doe',
#  'wonder',
#  'good',
#  'best.small',
#  'quantity',
#  'bt',
#  'achieve',
#  'alot',
#  'bhb.very',
#  'reliable',
#  'product',
#  'garnier',
#  'aha',
#  'bha.i',
#  'change',
#  'texture',
#  'hyperpigmented',
#  'area',
#  'day',
#  'good',
#  'product',
#  'perfect.b',
#  'product',
#  'get',
#  'great.b',
#  'product',
#  ' ',
#  'great.b',
#  'product',
#  'use',
#  'fast',
#  'delivery',
#  'quality.worth',
#  'price',
#  ' ',
#  'quality.worth',
#  'price',
#  ' ',
#  '.good',
#  'product',
#  '\n ',
#  'like',
#  'it.notice',
#  'change',
#  'day',
#  'use',
#  'product',
#  'review',
#  '.the',
#  'product',
#  'work',
#  ' ',
#  'face',
#  'mask.was',
#  'deliver',
#  'perfect',
#  'condition',
#  'work',
#  'great',
#  'love',
#  'it.best',
#  'product',
#  'like',
#  'it.b',
#  'product',
#  'use',
#  'like',
#  'quality.i',
#  'like',
#  'light',
#  'skin',
#  'remove',
#  'acne',
#  'marks.very',
#  'effective',
#  'cheap',
#  '\n ',
#  'quality.very',
#  'effective',
#  'acne',
#  'awesome.alway',
#  'reliable',
#  'product',
#  'best.its',
#  'legit',
#  'work',
#  'face',
#  'amazing.would',
#  'highly',
#  'recommend',
#  'product',
#  'love',
#  'it.have',
#  'disappoint',
#  ' ',
#  'love',
#  'work',
#  'like',
#  'it.mark',
#  'reduce',
#  'slow',
#  'sure',
#  'consistent',
#  'use',
#  'like',
#  'it.first',
#  'time',
#  'complain',
#  'satisfied.it',
#  'work',
#  '\n',
#  'nice',
#  'service',
#  'hate',
#  'it.the',
#  'good',
#  'thing',
#  'inside',
#  'air',
#  'work',
#  'content',
#  'little',
#  'compare',
#  'price',
#  'like',
#  'it.fast',
#  'delivery',
#  'delivery',
#  'experience',
#  'purchase',
#  'work',
#  'well.it',
#  'dome',
#  'feel',
#  'change',
#  'month',
#  'quality.product',
#  'expect',
#  ' ',
#  'quality.product',
#  'expect',
#  ' ',
#  'performance.it',
#  'lather',
#  'scent',
#  'durability.the',
#  'scent',
#  'amazing',
#  'last',
#  'long',
#  'love',
#  '.just',
#  'start',
#  'recently',
#  'work',
#  'face',
#  'mask.it',
#  'good',
#  'skin',
#  'love',
#  'it.just',
#  'start',
#  'best.keep',
#  'dry',
#  'smell',
#  'nice',
#  'best.it',
#  'good',
#  'face',
#  '3rd',
#  'buy',
#  'lightness.great',
#  'product',
#  'light',
#  'bad',
#  "product.can't",
#  'recommend',
#  'buy',
#  'like',
#  'it.it',
#  'easy',
#  'use',
#  'skin',
#  'friendly',
#  'wait',
#  'results.so',
#  'far',
#  'good',
#  'love',
#  'it.the',
#  'good',
#  'product',
#  'collection',
#  'soo',
#  'far',
#  'good',
#  "product.i've",
#  'see',
#  'improvement',
#  'week',
#  'love',
#  'it.i',
#  'get',
#  'order',
#  'fast',
#  'efficiently',
#  'like',
#  'it.affordable',
#  'makeup',
#  'remover.so',
#  'far',
#  'remove',
#  'makeup',
#  'dark',
#  'spot',
#  'corrector.work',
#  'good.work',
#  'efficiently',
#  'quality',
#  'stuff',
#  'amazing',
#  'good',
#  'best.for',
#  'oily',
#  'acne',
#  'skin',
#  'simply',
#  'best.i',
#  'absolutely',
#  'love',
#  'scrub/',
#  'mask/',
#  'cleanser',
#  'like',
#  'it.perfectly',
#  'work',
#  'not',
#  'without.best',
#  'thing',
#  'awesomeproduct.i',
#  'love',
#  'remove',
#  'dirt',
#  'cleance',
#  'skin',
#  'skin',
#  'improvement.my',
#  'skin',
#  'improve',
#  'start',
#  'love',
#  'quality',
#  'product',
#  'good',
#  'price',
#  'worth',
#  'wait',
#  '\r\n',
#  'inform',
#  'collect',
#  'product',
#  'sm',
#  'love',
#  'it!.quality',
#  'value',
#  'money',
#  'delivery.convenient',
#  'fast',
#  'efficient',
#  'acne',
#  'care',
#  'kit.it',
#  'come',
#  'handy',
#  'wow',
#  'spf30.great',
#  '.good',
#  'quality',
#  'love',
#  'it.simply',
#  'good',
#  'best.it',
#  'work',
#  'love',
#  'value',
#  'money.work',
#  'skin',
#  'love',
#  'smooth',
#  'foam',
#  'cleanser.i',
#  'feel',
#  'face',
#  'improve',
#  'considerably',
#  'tonne',
#  'best.perfect',
#  'quality',
#  ' ',
#  'like',
#  'clear',
#  'dirt',
#  'face',
#  'affordable',
#  'glow.make',
#  'skin',
#  'glow',
#  'love',
#  'it.feel',
#  'moisturize',
#  'screen',
#  'sunscreen',
#  'add',
#  'bonus',
#  'skin',
#  'care',
#  '.this',
#  'skin',
#  'care',
#  'routine',
#  ' ',
#  'quality.good',
#  'dope',
#  'notch',
#  'excellent.my',
#  'favourite',
#  'thing',
#  'best.my',
#  'dark',
#  'spot',
#  'visibly',
#  'reduce',
#  'service.the',
#  'product',
#  'work',
#  'magic',
#  '\n',
#  'deliver',
#  'time',
#  'garnier.it',
#  'smart',
#  'like',
#  'it.second',
#  'purchase',
#  'work',
#  'buy',
#  'dark',
#  'spot',
#  'corrector.work',
#  'love',
#  'it.keeps',
#  'face',
#  'matte',
#  'clear',
#  'dark',
#  'spot',
#  'outbreak',
#  'love',
#  'it.my',
#  '3rd',
#  'year',
#  'product.it',
#  'amazing',
#  'love',
#  'love',
#  'product',
#  'great',
#  'product',
#  'great',
#  'age',
#  'deliver',
#  'product',
#  'total',
#  'turn',
#  'best.its',
#  'perfect',
#  'quality.my',
#  'skin',
#  'get',
#  'smooth',
#  'glow.leave',
#  'skin',
#  'glow',
#  'healthy',
#  'love',
#  'glow',
#  'skin.its',
#  'perfect',
#  'great',
#  'service.fast',
#  'delivery',
#  'convenient',
#  'receive',
#  'product',
#  'wanted',
#  'smooth',
#  'skin.this',
#  'work',
#  'use',
#  'twice',
#  'week',
#  'skin',
#  'improve',
#  'vastly',
#  'blemish',
#  'minimal',
#  'blackhead',
#  'clean',
#  'skin',
#  'glow',
#  'man',
#  'mean',
#  'thank',
#  'product',
#  '\r\n ',
#  'remove',
#  'black',
#  'spot.use',
#  'month',
#  'perfection!!!!!!!!remove',
#  'black',
#  'spot',
#  'good',
#  'quality.effective',
#  'good',
#  'good',
#  'awesome',
#  'job',
#  'fine.awesome',
#  'job',
#  'fine',
#  'ms.love',
#  'product',
#  'great',
#  'deal.both',
#  'great',
#  'product',
#  'benefit',
#  'affordable',
#  'like',
#  'it.i',
#  ...]

# %%
unique_tokens =
# Out:
# list

# %%
# Display the word cloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

# Initialize word cloud
wc = WordCloud()
wc.generate(positive_texts)

#Plot
plt.imshow(wc, interpolation="bilinear")
plt.show()

# %%
# Generate timestamps for starttime and end period

start_time = get_timestamp(["01-01-2023"])[0]

end_time = get_timestamp(["31-12-2023"])[0]

# %%
query = "what do the clients think about the price"

# generate query embedding
xq = retriever.encode(query)

# query pinecone with query embedding and period filter
result = index.query(xq, top_k=50, include_metadata=True, filter={})
